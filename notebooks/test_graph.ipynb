# %%
import sys
import os

# Add project root to the Python path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.nodes import search_node
from src.state import AgentState

state = AgentState(
    messages=[],
    search_query="impact of warm ischemia time on kidney transplant outcomes"
)

output = search_node(state)
output

# %%
from src.nodes import fetch_node
from src.state import AgentState

state = AgentState(
    urls=[
        "https://en.wikipedia.org/wiki/Kidney_transplantation"
    ]
)

fetch_node(state)

# %%
from src.graph import create_graph
from langchain_core.messages import HumanMessage

graph = create_graph()

result = graph.invoke(
    {"messages": [HumanMessage(content="Hello, who are you?")]}
)

result

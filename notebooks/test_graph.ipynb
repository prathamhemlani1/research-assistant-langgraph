# %%
import sys
import os

# Add project root to the Python path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.graph import create_graph
from langchain_core.messages import HumanMessage

graph = create_graph()

result = graph.invoke(
    {"messages": [HumanMessage(content="Hello, who are you?")]}
)

result
# Out:
# /Users/prathamhemlani/Desktop/research-assistant-langgraph/.venv/lib/python3.11/site-packages/pydantic/v1/main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)
# {'messages': [HumanMessage(content='Hello, who are you?', additional_kwargs={}, response_metadata={}, id='81593715-1894-499c-ad06-1736852c31bd'),
#   AIMessage(content='Hello! I’m an AI assistant designed to help you with information, answer questions, and provide support on various topics. How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 37, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CcgJq6hizkJlaLvPerTvDgBpSyDlz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--031a7c20-73f0-411f-8f65-64da17cdcfe2-0', usage_metadata={'input_tokens': 37, 'output_tokens': 31, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

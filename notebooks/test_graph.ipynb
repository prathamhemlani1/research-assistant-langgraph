# %%
import sys
import os

# Add project root to the Python path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.nodes import search_node
from src.state import AgentState

state = AgentState(
    messages=[],
    search_query="impact of warm ischemia time on kidney transplant outcomes"
)

output = search_node(state)
output
# Out:
# {'search_results': [{'url': 'https://www.nature.com/articles/srep36118',
#    'title': 'The influence of warm ischemia elimination on kidney injury during ...',
#    'content': 'Warm ischemia time, also called anastomosis time (WIT), is another potentially modifiable factor in kidney transplantation outcome.',
#    'score': 0.86303437,
#    'raw_content': None},
#   {'url': 'https://www.kidney-international.org/article/S0085-2538(15)00064-2/fulltext',
#    'title': 'Prolonged warm ischemia time is associated with graft failure and ...',
#    'content': 'Warm ischemia time is associated with adverse long-term patient and graft survival after kidney transplantation.',
#    'score': 0.8488849,
#    'raw_content': None},
#   {'url': 'https://annalsoftransplantation.com/abstract/full/idArt/916012',
#    'title': 'Implantation Warm Ischemia Time in Kidney Transplant Recipients',
#    'content': 'CONCLUSIONS: IT of more than 45 min was a risk factor for poor EGF, but achieved statistical significance only when it exceeded 60 min. Longer',
#    'score': 0.776708,
#    'raw_content': None},
#   {'url': 'https://pmc.ncbi.nlm.nih.gov/articles/PMC10272701/',
#    'title': 'The Impact of Combined Warm and Cold Ischemia Time on Post ...',
#    'content': 'Prolonged warm ischemia time (WIT) and cold ischemia time (CIT) are independently associated with post-transplant graft failure.',
#    'score': 0.7491794,
#    'raw_content': None},
#   {'url': 'https://pubmed.ncbi.nlm.nih.gov/32654278/',
#    'title': 'Impact of warm ischemia time on outcomes for kidneys donated after ...',
#    'content': 'Prolonged WIT and CIT are associated with increased DGF but not death-censored graft failure in recipients of DCD kidney transplants in the post-KAS era.',
#    'score': 0.72814995,
#    'raw_content': None}],
#  'urls': ['https://www.nature.com/articles/srep36118',
#   'https://www.kidney-international.org/article/S0085-2538(15)00064-2/fulltext',
#   'https://annalsoftransplantation.com/abstract/full/idArt/916012',
#   'https://pmc.ncbi.nlm.nih.gov/articles/PMC10272701/',
#   'https://pubmed.ncbi.nlm.nih.gov/32654278/']}

# %%
from src.graph import create_graph
from langchain_core.messages import HumanMessage

graph = create_graph()

result = graph.invoke(
    {"messages": [HumanMessage(content="Hello, who are you?")]}
)

result
